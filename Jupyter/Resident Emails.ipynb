# %%
import pandas as pd
data = pd.read_csv("./Desktop/James's Roster 2018-2019.csv")
data
# Out:
#     Unnamed: 0        Unnamed: 1   Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          NaN               NaN          NaN        NaN        NaN
# 1          NaN               NaN          NaN        NaN        NaN
# 2   BK-1304-1a           Hallett    Alexander  A14860996       MUIR
# 3   BK-1304-1b             Joshi      Nikhill  A14395716       MUIR
# 4   BK-1304-2a            Yafuso       Shendo  A15528931     WARREN
# 5   BK-1304-2b             Aslam         Umar  A15620013     WARREN
# 6   BK-1304-2c           Tillman       Connor  A15468335     WARREN
# 7   BK-1305-1a              Tsai    Chu-Hsien  A13817072     WARREN
# 8   BK-1305-1b        Rojo-Tapia      Adriana  A15299174       MUIR
# 9   BK-1305-1c            Jubran       Summer  A15322295       MUIR
# 10  BK-1305-2a           Hammoud     Monalisa  A14846300       MUIR
# 11  BK-1305-2b           Najduch       Alicja  A14934902       MUIR
# 12  BK-1305-2c          Gonzalez         Kate  A15325552       MUIR
# ...

# %%
data = data['Unnamed: 8']
for i in data:
    print(str(i))
# Out:
# nan
# nan
# ahallett@ucsd.edu
# n2joshi@ucsd.edu
# syafuso@ucsd.edu
# uaslam@ucsd.edu
# cptillma@ucsd.edu
# cht081@ucsd.edu
# arojotap@ucsd.edu
# sjubran@ucsd.edu
# mohammou@ucsd.edu
# anajduch@ucsd.edu
# kbgonzal@ucsd.edu
# faaceves@ucsd.edu
# mykidane@ucsd.edu
# s1schwar@ucsd.edu
# mskinner@ucsd.edu
# lduga@ucsd.edu
# hul104@ucsd.edu
# zow012@ucsd.edu
# agemawat@ucsd.edu
# xil621@ucsd.edu
# jhramire@ucsd.edu
# kasalgad@ucsd.edu
# cqn016@ucsd.edu
# m7alam@ucsd.edu
# zeflores@ucsd.edu
# kheisser@ucsd.edu
# jballard@ucsd.edu
# jtancinc@ucsd.edu
# arohozin@ucsd.edu
# joy001@ucsd.edu
# doz026@ucsd.edu
# j3yoo@ucsd.edu
# nvandamm@ucsd.edu
# ckamita@ucsd.edu
# sumurill@ucsd.edu
# cht096@ucsd.edu
# cyg022@ucsd.edu
# dlay@ucsd.edu
# kemonten@ucsd.edu
# alm135@ucsd.edu
# ereza@ucsd.edu
# zsomma@ucsd.edu
# snmercad@ucsd.edu
# kichuong@ucsd.edu
# aya003@ucsd.edu
# kynoh@ucsd.edu
# jmezagon@ucsd.edu
# fevaldez@ucsd.edu
# hgelle@ucsd.edu
# d1kay@ucsd.edu
# xhcao@ucsd.edu
# frwu@ucsd.edu
# ...
